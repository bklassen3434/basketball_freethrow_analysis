# %%
from animate import animate_trial
import json
from biomechanics import *
from helper import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
# Plot to show the AVERAGE ENERGY EFFICIENCY of all joints across ALL TRIALS

joints = ['R_ELBOW', 'L_ELBOW', 'R_KNEE', 'L_KNEE', 'R_HIP', 'L_HIP', 'R_SHOULDER', 'L_SHOULDER']

fig, ax = plt.subplots(figsize = (12, 6))

colors = plt.cm.get_cmap('tab10', len(joints))
print(colors(0))

avg_eff = []
result = []
colors = []
average_efficiencies = {key: [] for key in joints}
for trial in range(125):
    trial_efficiencies = 
    for joint in joints:
        average_efficiencies[joint].append(average_kinetic_energy_efficiency(joint, trial))

for i, joint in enumerate(average_efficiencies.keys()):
    print(len(average_efficiencies[joint]))
    ax.plot(range(len(average_efficiencies[joint])), average_efficiencies[joint], color=colors(i), label=joint, linestyle='-')


plt.legend()
plt.xlabel('Trial')
plt.ylabel('Kinetic Energy Efficiency (After/Before)')
plt.title(f'Average Energy Transfer Efficiency')
plt.show()

# %%
#DOGSHIT

# # Plot to show AVERAGE TOTAL KINETIC ENERGY EFFICIENCY of body parts across ALL TRIALS

# aligned_data = align_tracking_data(data)

# joints = {'R_ELBOW':[[('R_SHOULDER', 'R_ELBOW'),'upper_arm'],
#                      [('R_ELBOW', 'R_WRIST'), 'forearm',]],
#         'L_ELBOW': [[('L_SHOULDER', 'L_ELBOW'), 'upper_arm'],
#                     [('L_ELBOW', 'L_WRIST'), 'forearm',]],

#         'R_KNEE': [[('R_KNEE', 'R_ANKLE'), 'lower_leg'],
#                     [('R_HIP', 'R_KNEE'), 'thigh',]],
#         'L_KNEE': [[('L_KNEE', 'L_ANKLE'), 'lower_leg'],
#                     [('L_HIP', 'L_KNEE'), 'thigh',]],

#         'R_HIP': [[('R_HIP', 'R_KNEE'), 'thigh',],
#                    [('R_SHOULDER', 'R_HIP'), 'trunk_vertical',]],
#         'L_HIP': [[('L_HIP', 'L_KNEE'), 'thigh',],
#                   [('L_SHOULDER', 'L_HIP'), 'trunk_vertical',]],

#         'R_SHOULDER': [[('R_SHOULDER', 'R_HIP'), 'trunk_vertical',],
#                    [('R_SHOULDER', 'R_ELBOW'),'upper_arm']],
#         'L_SHOULDER': [[('L_SHOULDER', 'L_HIP'), 'trunk_vertical',],
#                   [('L_SHOULDER', 'L_ELBOW'),'upper_arm']],}

# total_efficiencies_per_frame = {key: [] for key in joints.keys()}

# for trial in range(len(aligned_data)):

#     num_frames = len(aligned_data[trial]['tracking'])
#     trial_efficiencies = {key: [] for key in joints.keys()} 

#     for joint in joints.keys():

#         for frame in range(num_frames-2):

#             trial_efficiencies[joint].append(kinetic_energy_efficiency(joint, frame, trial))

#     for joint in joints.keys():
#         total_efficiencies_per_frame[joint].append(trial_efficiencies[joint])

# average_efficiencies = {key: np.mean(total_efficiencies_per_frame[key], axis=0) for key in total_efficiencies_per_frame.keys()}

# fig, ax = plt.subplots(figsize = (8, 8))

# colors = plt.cm.get_cmap('tab10', len(joints.keys()))

# for i, joint in enumerate(average_efficiencies.keys()):
#     ax.plot(range(len(average_efficiencies[joint])), average_efficiencies[joint], color=colors(i), label=joint, linestyle='-')

# # Add vertical line to find when the ball is released
# ax.axvline(30, color='black', linestyle='--')
# ax.text(32, 1, f'Ball is\nReleased', color='black', verticalalignment='bottom')

# plt.legend()
# plt.xlabel('Frame')
# plt.ylabel('Kinetic Energy Efficiency (%)')
# plt.title('Average Kinetic Energy Efficiency over All Free Throws')
# plt.xlim(0,43)
# plt.show()

# %%
# Plot to show AVERAGE TOTAL KINETIC ENERGIES of body parts across ALL TRIALS

aligned_data = align_tracking_data(data)

selected = {
    'upper_arm': [('R_SHOULDER', 'R_ELBOW'), ('L_SHOULDER', 'L_ELBOW')],
    'forearm': [('R_ELBOW', 'R_WRIST'), ('L_ELBOW', 'L_WRIST')],
    'thigh': [('R_HIP', 'R_KNEE'), ('L_HIP', 'L_KNEE')],
    'lower_leg': [('R_KNEE', 'R_ANKLE'), ('L_KNEE', 'L_ANKLE')],
}

total_energies_per_frame = {key: [] for key in selected.keys()}

for trial in range(len(aligned_data)):

    num_frames = len(aligned_data[trial]['tracking'])
    trial_energies = {key: [] for key in selected.keys()} 

    for body_part, joints_list in selected.items():

        for joints in joints_list:

            for frame in range(num_frames-1):

                trial_energies[body_part].append(kinetic_energy_total(body_part, joints[0], joints[1], frame, trial))

    for body_part in selected.keys():
        total_energies_per_frame[body_part].append(trial_energies[body_part])

average_energies = {key: np.mean(total_energies_per_frame[key], axis=0) for key in total_energies_per_frame.keys()}

fig, ax = plt.subplots(figsize = (8, 8))

colors = plt.cm.get_cmap('tab10', len(selected.keys()))

for i, body_part in enumerate(average_energies.keys()):
    ax.plot(range(len(average_energies[body_part])), average_energies[body_part], color=colors(i), label=body_part, linestyle='-')

# Add vertical line to find when the ball is released
ax.axvline(30, color='black', linestyle='--')
ax.text(32, 1, f'Ball is\nReleased', color='black', verticalalignment='bottom')

plt.legend()
plt.xlabel('Frame')
plt.ylabel('Kinetic Energy (J)')
plt.title('Average Kinetic Energy over All Free Throws')
plt.xlim(0,45)
plt.show()

# %%
# animate_trial(trial=113, energy=True, azim=320, player_color='green')

# %%
# # Load Data (get data from every free throw)
# data = []

# for trial_number in range(1,126):

#     trial_id = str(trial_number).zfill(4)

#     with open(f'./data/P0001/BB_FT_P0001_T{trial_id}.json') as json_file:
#         free_throw_data = json.load(json_file)
#         data.append(free_throw_data)

# align_tracking_data(data)

# %%
# # Plot to show the RELATIVE ENERGY CONTRIBUTIONS of the right and left sides for all free throws

# fig, ax = plt.subplots(figsize = (12, 6))

# # for i, joint in enumerate(selected):
# rel_eng = []
# result = []
# colors = []
# for trial in range(125):
#     rel_eng.append(relative_energy_contribution(trial))
#     result.append(data[trial]['result'])
#     if result[-1] == 'missed':
#         colors.append('red')
#     elif result[-1] == 'made':
#         colors.append('green')
# ax.scatter((range(125)), rel_eng, color = colors)

# # Create custom legend handles
# legend_elements = [Line2D([0], [0], marker='o', color='w', label='Made',
#                            markerfacecolor='green', markersize=10),
#                    Line2D([0], [0], marker='o', color='w', label='Missed',
#                            markerfacecolor='red', markersize=10)]

# # Add the legend to the plot
# ax.legend(handles=legend_elements)

# plt.xlabel('Trial')
# plt.ylabel('Energy Contribution from the Right Side of the Body (%)')
# plt.title('Percent Energy Contribution from the RIGHT Side of the Body')
# plt.show()

# %%
# Plot to show the AVERAGE ENERGY EFFICIENCY of a joint for all free throws
joint = 'R_KNEE'

fig, ax = plt.subplots(figsize = (12, 6))

# for i, joint in enumerate(selected):
avg_eff = []
result = []
colors = []
for trial in range(125):
    avg_eff.append(average_kinetic_energy_efficiency(joint, trial))
    result.append(data[trial]['result'])
    if result[-1] == 'missed':
        colors.append('red')
    elif result[-1] == 'made':
        colors.append('green')
ax.scatter((range(125)), avg_eff, color = colors)

# Create custom legend handles
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Made',
                           markerfacecolor='green', markersize=10),
                   Line2D([0], [0], marker='o', color='w', label='Missed',
                           markerfacecolor='red', markersize=10)]

# Add the legend to the plot
ax.legend(handles=legend_elements)

plt.xlabel('Trial')
plt.ylabel('Kinetic Energy Efficiency (After/Before)')
plt.title(f'Average Energy Transfer Efficiency for the {joint}')
plt.show()

# %%
# # Plot to show ENERGY TRANSFER EFFICIENCY of joints over the length of the freethrow
# trial = 1

# # selected = ['R_ELBOW', 'L_ELBOW', 'R_SHOULDER', 'L_SHOULDER', 'R_KNEE', 'L_KNEE', 'R_HIP', 'L_HIP']
# selected = ['R_ELBOW', 'L_ELBOW',]

# colors = plt.cm.get_cmap('tab10', len(selected))

# fig, ax = plt.subplots(figsize = (8, 8))

# start = 0
# end = 43

# for i, joint in enumerate(selected):
#     eff = []
#     for frame in range(start, end):
#         eff.append(kinetic_energy_efficiency(joint, frame, trial))
#     ax.scatter((range(start, end)), eff, color = colors(i), label = f'{joint}')

# # Add vertical line to find when the ball is released
# ax.axvline(30, color='black', linestyle='--')
# ax.text(30, 4, f'Ball is\nReleased', color='black', verticalalignment='bottom')

# plt.legend()
# plt.xlabel('Frame')
# plt.ylabel('Kinetic Energy Efficiency (After/Before)')
# plt.title('Kinetic Energy Transfer Efficiency')
# plt.xlim(0, 45)
# # plt.ylim(0,25)
# plt.show()

# %%
# # Get the peak kinetic energy of the thigh of each trial

# peak_frames = []

# for trial in range(1, 125):
#     r_thigh = []
#     l_thigh = []
#     for frame in range(130, ball_leaves_hands(trial)):
#         r_thigh.append(kinetic_energy_total('thigh', 'R_HIP', 'R_KNEE', frame, trial))
#         l_thigh.append(kinetic_energy_total('thigh', 'L_HIP', 'L_KNEE', frame, trial))
#     ind = int((r_thigh.index(max(r_thigh)) + l_thigh.index(max(l_thigh))) / 2)
#     peak_frames.append(130 + ind)
# min(peak_frames), max(peak_frames)

# %%
# # Plot to show TOTAL KINETIC ENERGIES of body parts over the length of the freethrow
# trial = 113

# selected = {('R_SHOULDER', 'R_ELBOW'):'upper_arm',
#             ('L_SHOULDER', 'L_ELBOW'): 'upper_arm',
#             ('R_ELBOW', 'R_WRIST'): 'forearm',
#             ('L_ELBOW', 'L_WRIST'): 'forearm',

#             ('R_HIP', 'R_KNEE'): 'thigh',
#             ('L_HIP', 'L_KNEE'): 'thigh',
#             ('R_KNEE', 'R_ANKLE'): 'lower_leg',
#             ('L_KNEE', 'L_ANKLE'): 'lower_leg',}

# colors = plt.cm.get_cmap('tab10', len(selected.keys()))

# fig, ax = plt.subplots(figsize = (8, 8))

# for i, joints in enumerate(selected.keys()):
#     energ = []
#     for frame in range(0, 43):
#         energ.append(kinetic_energy_total(selected[joints], joints[0], joints[1], frame, trial))
#     ax.scatter((range(0,43)), energ, color = colors(i), label = f'{joints[0][0]}_{selected[joints]}')


# # # Plot vertical lines to indicate phases of movement
# # for loc, label in zip([165, 170, 175], ['Load', 'Release', 'Follow \nThrough']):
# #     ax.axvline(loc, color='black', linestyle='--')
# #     # Optionally, annotate the plot with the value of the maximum energy
# #     ax.text(loc + 1, 4.5, f'{label}', color='black', verticalalignment='bottom')

# # Add vertical line to find when the ball is released
# ax.axvline(30, color='black', linestyle='--')
# ax.text(25, 1.0, f'Ball is\nReleased', color='black', verticalalignment='bottom')

# plt.legend()
# plt.xlabel('Frame')
# plt.ylabel('Kinetic Energy (J)')
# plt.title('Kinetic Energy over the Free Throw')
# plt.xlim(0, 45)
# plt.show()

# %%
# # Plot to show DISPLACEMENT of joints over the length of the freethrow
# trial = 1

# sequence = {('R_SHOULDER', 'R_ELBOW'):'upper_arm',
#             ('L_SHOULDER', 'L_ELBOW'): 'upper_arm',
#             ('R_ELBOW', 'R_WRIST'): 'forearm',
#             ('L_ELBOW', 'L_WRIST'): 'forearm',

#             ('R_HIP', 'R_KNEE'): 'thigh',
#             ('L_HIP', 'L_KNEE'): 'thigh',
#             ('R_KNEE', 'R_ANKLE'): 'lower_leg',
#             ('L_KNEE', 'L_ANKLE'): 'lower_leg',

#             ('R_SHOULDER', 'R_HIP'): 'trunk_vertical',
#             ('L_SHOULDER', 'L_HIP'): 'trunk_vertical',
#             ('R_SHOULDER', 'L_SHOULDER'): 'trunk_horizontal',
#             ('R_HIP', 'L_HIP'): 'trunk_horizontal',

#             }

# fig, ax = plt.subplots(3, 1, figsize = (12, 8))

# colors = plt.cm.get_cmap('tab10', len(sequence.keys()))

# for d in range(3):
#     for i, joints in enumerate(sequence.keys()):
#         rvel = []
#         for frame in range(0, 43):
#             rvel.append(distance(joints[0], joints[1], frame, trial)[d])
#         ax[d].scatter((range(0,43)), rvel, color=colors(i), label = joints)

# plt.legend()
# plt.xlabel('Frame')
# plt.ylabel('Distance (m)')
# plt.show()

# %%
# # Plot to show ROTATIONAL KINETIC ENERGIES of body parts over the length of the freethrow
# sequence = {('R_SHOULDER', 'R_ELBOW'):'upper_arm',
#             ('L_SHOULDER', 'L_ELBOW'): 'upper_arm',
#             ('R_ELBOW', 'R_WRIST'): 'forearm',
#             ('L_ELBOW', 'L_WRIST'): 'forearm',

#             ('R_HIP', 'R_KNEE'): 'thigh',
#             ('L_HIP', 'L_KNEE'): 'thigh',
#             ('R_KNEE', 'R_ANKLE'): 'lower_leg',
#             ('L_KNEE', 'L_ANKLE'): 'lower_leg',

#             ('R_SHOULDER', 'R_HIP'): 'trunk_vertical',
#             ('L_SHOULDER', 'L_HIP'): 'trunk_vertical',
#             ('R_SHOULDER', 'L_SHOULDER'): 'trunk_horizontal',
#             ('R_HIP', 'L_HIP'): 'trunk_horizontal',
#             }

# trial = 1

# fig, ax = plt.subplots(figsize = (8, 8))

# colors = plt.cm.get_cmap('tab10', len(sequence.keys()))

# for i, joints in enumerate(sequence.keys()):
#     energ = []
#     for frame in range(0,43):
#         energ.append(kinetic_energy_rot(sequence[joints], joints[0], joints[1], frame, trial))
#     ax.scatter(range(0,43), energ, color=colors(i), label = joints)

# plt.legend()
# plt.xlabel('Frame')
# plt.ylabel('Kinetic Energy (J)')
# plt.title('Rotational Kinetic Energy per Frame')
# # plt.ylim(0, 2000)
# plt.show()

# %%
# # Plot to show TRANSLATIONAL KINETIC ENERGIES of body parts over the length of the freethrow
# sequence = {('R_SHOULDER', 'R_ELBOW'):'upper_arm',
#             ('L_SHOULDER', 'L_ELBOW'): 'upper_arm',
#             ('R_ELBOW', 'R_WRIST'): 'forearm',
#             ('L_ELBOW', 'L_WRIST'): 'forearm',

#             ('R_HIP', 'R_KNEE'): 'thigh',
#             ('L_HIP', 'L_KNEE'): 'thigh',
#             ('R_KNEE', 'R_ANKLE'): 'lower_leg',
#             ('L_KNEE', 'L_ANKLE'): 'lower_leg',

#             ('R_SHOULDER', 'R_HIP'): 'trunk_vertical',
#             ('L_SHOULDER', 'L_HIP'): 'trunk_vertical',
#             ('R_SHOULDER', 'L_SHOULDER'): 'trunk_horizontal',
#             ('R_HIP', 'L_HIP'): 'trunk_horizontal',
#             }

# trial = 1

# fig, ax = plt.subplots(figsize = (8, 8))

# colors = plt.cm.get_cmap('tab10', len(sequence.keys()))

# for i, joints in enumerate(sequence.keys()):
#     energ = []
#     for frame in range(0,43):
#         energ.append(kinetic_energy_trans(sequence[joints], joints[0], joints[1], frame, trial))
#     ax.scatter((range(0,43)), energ, color=colors(i), label = sequence[joints])

# plt.legend()
# plt.xlabel('Frame')
# plt.ylabel('Kinetic Energy (J)')
# plt.show()

# %%
# # Plot to show TRANSLATIONAL VELOCITIES of body parts over the length of the freethrow
# fig, ax = plt.subplots(3, 1, figsize = (12, 8))

# colors = plt.cm.get_cmap('tab10', len(['R_ELBOW', 'L_ELBOW', 'R_SHOULDER', 'L_SHOULDER',
#                             'R_KNEE', 'L_KNEE', 'R_HIP', 'L_HIP']))

# for d in range(3):
#     for i, joint in enumerate(['R_ELBOW', 'L_ELBOW', 'R_SHOULDER', 'L_SHOULDER',
#                                 'R_KNEE', 'L_KNEE', 'R_HIP', 'L_HIP']):
#         vel = []
#         for frame in range(len(free_throw_data['tracking']) - 1):
#             vel.append(velocity_trans(joint, frame)[d])
#         ax[d].scatter((range(len(free_throw_data['tracking']) - 1)), vel, color=colors(i), label = joint)

# plt.legend()
# plt.xlabel('Frame')
# plt.ylabel('Velocity (m/s)')
# plt.show()

# %%
# # Plot to show ROTATIONAL VELOCITIES of body parts over the length of the freethrow
# fig, ax = plt.subplots(figsize = (12, 8))

# colors = plt.cm.get_cmap('tab10', len(sequence.keys()))

# # for d in range(3):
# for i, joints in enumerate(sequence.keys()):
#     rvel = []
#     for frame in range(len(free_throw_data['tracking']) - 1):
#         rvel.append(rot_velocity(joints[0], joints[1], frame))
#     ax.scatter((range(len(free_throw_data['tracking']) - 1)), rvel, color=colors(i), label = joints)

# plt.legend()
# plt.xlabel('Frame')
# plt.ylabel('Velocity (/s)')
# plt.show()

# %%
# # Plot to show SMOOTHED EFFICIENCY of energy transfer over the length of the freethrow
# fig, ax = plt.subplots(figsize = (8, 8))

# colors = plt.cm.get_cmap('tab10', len(joints))

# for i, joint in enumerate(['R_KNEE', 'L_KNEE']):
#     eff = ema(joint, alpha = 0.4)
#     ax.scatter((range(len(free_throw_data['tracking']) - 1)), eff, color=colors(i), label = joint)

# plt.legend()
# plt.show()
